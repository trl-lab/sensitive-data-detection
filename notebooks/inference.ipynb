# %%
pip install pycountry langdetect
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set sys path to root directory
import sys
sys.path.append('..')

# %% [markdown]
# ## Input: Single csv

# %%
single_csv_path = r"C:\Users\VN\Documents\GitHub\detecting-sensitive-data\utilities\data\csv\Cameroon Social Development.csv"

from utilities.data_processor import DataLoader

single_csv_data = DataLoader().load_single_file(single_csv_path)

single_csv_data
# Out:
# Unsloth not installed
# Name model in model.py: gpt-4o-mini
# OpenAI client initialized
# {'Cameroon Social Development': {'metadata': {'country': 'Cameroon',
#    'filename': 'Cameroon Social Development.csv',
#    'filepath': 'C:\\Users\\VN\\Documents\\GitHub\\detecting-sensitive-data\\utilities\\data\\csv\\Cameroon Social Development.csv',
#    'table_name': 'Cameroon Social Development',
#    'file_extension': '.csv',
#    'file_size_bytes': 104756,
#    'processing_timestamp': '2025-06-26T15:23:55.420008',
#    'total_columns': 6,
#    'max_records_per_column': 20,
#    'column_names': ['Country Name',
#     'Country ISO3',
#     'Year',
#     'Indicator Name',
#     'Indicator Code',
#     'Value'],
#    'column_types': {'Country Name': 'object',
#     'Country ISO3': 'object',
#     'Year': 'object',
#     'Indicator Name': 'object',
#     'Indicator Code': 'object',
#     'Value': 'object'}},
#   'columns': {'Country Name': {'records': ['#country+name',
#      'Cameroon',
# ...

# %% [markdown]
# ## Input folder with csv files

# %%
csv_folder_path = r"C:\Users\VN\Documents\GitHub\detecting-sensitive-data\utilities\data\csv"

from utilities.data_processor import DataLoader

csv_data = DataLoader().load_folder(csv_folder_path)

csv_data
# Out:
# {'Cameroon Social Development': {'metadata': {'country': None,
#    'country_info': {'raw_country': 'Cameroon Social Development.csv',
#     'standardized_name': None,
#     'alpha_2': None,
#     'alpha_3': None,
#     'standardization_confidence': 0.0,
#     'extraction_method': 'failed'},
#    'filename': 'Cameroon Social Development.csv',
#    'filepath': 'C:\\Users\\VN\\Documents\\GitHub\\detecting-sensitive-data\\utilities\\data\\csv\\Cameroon Social Development.csv',
#    'table_name': 'Cameroon Social Development',
#    'file_extension': '.csv',
#    'file_size_bytes': 104756,
#    'processing_timestamp': '2025-06-26T15:15:58.063390',
#    'total_columns': 6,
#    'max_records_per_column': 20,
#    'column_names': ['Country Name',
#     'Country ISO3',
#     'Year',
#     'Indicator Name',
#     'Indicator Code',
#     'Value'],
#    'column_types': {'Country Name': 'object',
#     'Country ISO3': 'object',
#     'Year': 'object',
#     'Indicator Name': 'object',
# ...

# %% [markdown]
# ## Input: Processed JSON

# %%
json_path = r"C:\Users\VN\Documents\GitHub\detecting-sensitive-data\utilities\data\personal_dummy.json"

json_data = DataLoader().load_single_file(json_path)

json_data
# Out:
# {'education.faculty_3.csv': {'columns': {'id': {'records': ['__export__.education_faculty_1_60e07e93',
#      '__export__.education_faculty_65_42964889',
#      '__export__.education_faculty_66_43796f89',
#      '__export__.education_faculty_67_0c3861f2',
#      '__export__.education_faculty_68_3c2cfc4e'],
#     'pii_gt': 'GENERIC_ID',
#     'sensitivity_gt': 0,
#     'pii_gt_sensitivity_gpt-4o': 'NON_SENSITIVE',
#     'pii_gt_sensitivity_gpt-4o-mini': 'NON_SENSITIVE',
#     'pii_gemma-2-9b_ft_PII_epochs_1': 'GENERIC_ID',
#     'pii_gemma-3-12b-it': 'GENERIC_ID',
#     'pii_gemma-2-9b-it': 'GENERIC_ID',
#     'pii_gpt-4o-mini': 'None',
#     'pii_aya-expanse-8b': 'None',
#     'pii_gemma-3-27b-it': 'GENERIC_ID',
#     'pii_no_records_gpt-4o': 'GENERIC_ID',
#     'pii_gpt-4o': 'GENERIC_ID',
#     'pii_no_records_gpt-4o-mini': 'None',
#     'pii_gpt-4o-mini_sensitivity_level_gpt-4o-mini': 'NON_SENSITIVE',
#     'pii_gpt-4o-mini_prompt_gpt-4o-mini': 'GENERIC_ID',
# ...

# %% [markdown]
# ## Language detection

# %%
from utilities.utils import detect_language
import pandas as pd

df = pd.read_csv(r"C:\Users\VN\Documents\GitHub\detecting-sensitive-data\utilities\data\csv\Cameroon Social Development.csv")

# COnvert dataframe to string
df_string = df.to_string()

df_lang = detect_language(df_string)
# Out:
# 'en'

# %% [markdown]
# # PII Detection and Reflection

# %%
pip install openai dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from utilities.detect_reflect import detect_and_reflect_pii
from llm_model.model import Model
from utilities.sensitivityClassifier import SensitivityClassifier

generator = SensitivityClassifier("gpt-4o-mini")
for key, value in single_csv_data.items():
    print(key)
    value = detect_and_reflect_pii(value, generator)

single_csv_data
# Out:
# Unsloth not installed
# Name model in model.py: gpt-4o-mini
# OpenAI client initialized
# Cameroon Social Development
# {'Cameroon Social Development': {'metadata': {'country': None,
#    'country_info': {'raw_country': 'Cameroon Social Development.csv',
#     'standardized_name': None,
#     'alpha_2': None,
#     'alpha_3': None,
#     'standardization_confidence': 0.0,
#     'extraction_method': 'failed'},
#    'filename': 'Cameroon Social Development.csv',
#    'filepath': 'C:\\Users\\VN\\Documents\\GitHub\\detecting-sensitive-data\\utilities\\data\\csv\\Cameroon Social Development.csv',
#    'table_name': 'Cameroon Social Development',
#    'file_extension': '.csv',
#    'file_size_bytes': 104756,
#    'processing_timestamp': '2025-06-26T15:15:58.048250',
#    'total_columns': 6,
#    'max_records_per_column': 20,
#    'column_names': ['Country Name',
#     'Country ISO3',
#     'Year',
#     'Indicator Name',
#     'Indicator Code',
#     'Value'],
# ...

# %%
from utilities.detect_reflect import detect_non_pii
from utilities.sensitivityClassifier import SensitivityClassifier

generator = SensitivityClassifier("gpt-4o-mini")
for key, value in single_csv_data.items():
    print(key)
    value = detect_non_pii(value, generator, key)

single_csv_data
# Out:
# Name model in model.py: gpt-4o-mini
# OpenAI client initialized
# Cameroon Social Development
# ISP used: 20240811 Information Sharing Protocol for Somalia HCT endorsed
#
# ### Instruction:
# You are a data governance assistant. Your task is to determine the overall sensitivity level of this table, based strictly on the provided Information Sharing Protocols (ISP) and the table's content and state which columns make the table sensitive.
#
# Follow these exact steps
#
# 1. Analyze the table schema AND the records of the table.
# 2. Use the ISP sensitivity levels: NON_SENSITIVE, MODERATE_SENSITIVE, HIGH_SENSITIVE, SEVERE_SENSITIVE. Only assign a sensitivity level if explicitly supported by ISP guidance.
# 3. Identify ONLY the columns that are sensitive on their own OR that become sensitive in combination with others, DIRECTLY supported by ISP guidance.
# ...

# %%
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/622M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# thinking content: <think>
# Okay, the user wants a short introduction to large language models. Let me start by defining what they are. Large language models (LLMs) are AI systems trained on vast amounts of text data. I should mention their key features like natural language understanding and generation.
#
# ...
